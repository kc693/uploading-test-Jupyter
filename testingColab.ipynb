# %%
2/32
# Out:
# 0.0625

# %% [markdown]
# hi

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([3,4,5,6])
y = np.array([10,7,14,13])

# %%
plt.figure('random plot')
plt.plot(x,y,color='blue',linewidth=0.8)

# %%
plt.figure('adfdafafd')
